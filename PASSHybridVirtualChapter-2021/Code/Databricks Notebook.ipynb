# %%
mount = "/mnt/data"
scope_name = "kvValues"

if(dbutils.fs.ls(mount)) : dbutils.fs.unmount(mount)

storeKey = dbutils.secrets.get(scope=scope_name,key="storageKey")

dbutils.fs.mount(
source = "wasbs://lakehouse@synstore01.blob.core.windows.net",
mount_point = mount,
extra_configs = {"fs.azure.account.key.synstore01.blob.core.windows.net":storeKey})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/data has been unmounted.
# Out[11]: True</div>

# %%
# %fs ls /mnt/data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/data/raw/</td><td>raw/</td><td>0</td></tr><tr><td>dbfs:/mnt/data/tables/</td><td>tables/</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
--clean up hive
DROP TABLE IF EXISTS OrderDetailLines;
DROP TABLE IF EXISTS OrderHeader;
DROP VIEW IF EXISTS lakehouse.OrderAggregation;
DROP TABLE IF EXISTS lakehouse.OrderDetailLines;
DROP TABLE IF EXISTS lakehouse.OrderHeader;
DROP DATABASE IF EXISTS lakehouse;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE DATABASE IF NOT EXISTS lakehouse;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
basePath = '/mnt/data'

headersQuery = "CREATE TABLE IF NOT EXISTS lakehouse.OrderHeader USING DELTA LOCATION '{}/tables/OrderHeader'".format(basePath)
linesQuery = "CREATE TABLE IF NOT EXISTS lakehouse.OrderDetailLines USING DELTA LOCATION '{}/tables/OrderDetailLines'".format(basePath)
sqlContext.sql(headersQuery)
sqlContext.sql(linesQuery)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: DataFrame[]</div>

# %%
# %sql

select * from lakehouse.OrderHeader
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesOrderID</th><th>RevisionNumber</th><th>OrderDate</th><th>DueDate</th><th>ShipDate</th><th>Status</th><th>OnlineOrderFlag</th><th>SalesOrderNumber</th><th>PurchaseOrderNumber</th><th>AccountNumber</th><th>CustomerID</th><th>ShipToAddressID</th><th>BillToAddressID</th><th>ShipMethod</th><th>CreditCardApprovalCode</th><th>SubTotal</th><th>TaxAmt</th><th>Freight</th><th>TotalDue</th><th>Comment</th><th>rowguid</th><th>ModifiedDate</th></tr></thead><tbody><tr><td>71774</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-06-08T00:00:00.000+0000</td><td>5</td><td>false</td><td>SO71774</td><td>PO348186287</td><td>10-4020-000609</td><td>29847</td><td>1092</td><td>1092</td><td>CARGO TRANSPORT 5</td><td>null</td><td>880.3484</td><td>70.4279</td><td>22.0087</td><td>972.7850</td><td>null</td><td>89e42cdc-8506-48a2-b89b-eb3e64e3554e</td><td>2008-06-08T00:00:00.000+0000</td></tr><tr><td>71776</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-06-08T00:00:00.000+0000</td><td>5</td><td>false</td><td>SO71776</td><td>PO19952192051</td><td>10-4020-000106</td><td>30072</td><td>640</td><td>640</td><td>CARGO TRANSPORT 5</td><td>null</td><td>78.8100</td><td>6.3048</td><td>1.9703</td><td>87.0851</td><td>null</td><td>8a3448c5-e677-4158-a29b-dd33069be0b0</td><td>2008-06-08T00:00:00.000+0000</td></tr><tr><td>71780</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-06-08T00:00:00.000+0000</td><td>5</td><td>false</td><td>SO71780</td><td>PO19604173239</td><td>10-4020-000340</td><td>30113</td><td>653</td><td>653</td><td>CARGO TRANSPORT 5</td><td>null</td><td>38418.6895</td><td>3073.4952</td><td>960.4672</td><td>42452.6519</td><td>null</td><td>a47665d2-7ac9-4cf3-8a8b-2a3883554284</td><td>2008-06-08T00:00:00.000+0000</td></tr><tr><td>71782</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-06-08T00:00:00.000+0000</td><td>5</td><td>false</td><td>SO71782</td><td>PO19372114749</td><td>10-4020-000582</td><td>29485</td><td>1086</td><td>1086</td><td>CARGO TRANSPORT 5</td><td>null</td><td>39785.3304</td><td>3182.8264</td><td>994.6333</td><td>43962.7901</td><td>null</td><td>f1be45a5-5c57-4a50-93c6-5f8be44cb7cb</td><td>2008-06-08T00:00:00.000+0000</td></tr><tr><td>71783</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-06-08T00:00:00.000+0000</td><td>5</td><td>false</td><td>SO71783</td><td>PO19343113609</td><td>10-4020-000024</td><td>29957</td><td>992</td><td>992</td><td>CARGO TRANSPORT 5</td><td>null</td><td>83858.4261</td><td>6708.6741</td><td>2096.4607</td><td>92663.5609</td><td>null</td><td>7db2329e-6446-42a8-8915-9c8370b68ed8</td><td>2008-06-08T00:00:00.000+0000</td></tr><tr><td>71784</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-06-08T00:00:00.000+0000</td><td>5</td><td>false</td><td>SO71784</td><td>PO19285135919</td><td>10-4020-000448</td><td>29736</td><td>659</td><td>659</td><td>CARGO TRANSPORT 5</td><td>null</td><td>108561.8317</td><td>8684.9465</td><td>2714.0458</td><td>119960.8240</td><td>null</td><td>ca31f324-2c32-4f8d-95eb-596e7f343027</td><td>2008-06-08T00:00:00.000+0000</td></tr><tr><td>71796</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-06-08T00:00:00.000+0000</td><td>5</td><td>false</td><td>SO71796</td><td>PO17052159664</td><td>10-4020-000420</td><td>29660</td><td>1058</td><td>1058</td><td>CARGO TRANSPORT 5</td><td>null</td><td>57634.6342</td><td>4610.7707</td><td>1440.8659</td><td>63686.2708</td><td>null</td><td>917ef5ba-f32d-4563-8588-66db0bcdc846</td><td>2008-06-08T00:00:00.000+0000</td></tr><tr><td>71797</td><td>2</td><td>2008-06-01T00:00:00.000+0000</td><td>2008-06-13T00:00:00.000+0000</td><td>2008-0 ...

# %%
# %sql
SELECT
    h.SalesOrderNumber,
    COUNT(l.SalesOrderDetailID) AS RecordCount
FROM
    lakehouse.OrderHeader h
    INNER JOIN lakehouse.OrderDetailLines l
        ON h.SalesOrderID = l.SalesOrderID
GROUP BY
    h.SalesOrderNumber
HAVING
    RecordCount > 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesOrderNumber</th><th>RecordCount</th></tr></thead><tbody><tr><td>SO71831</td><td>3</td></tr><tr><td>SO71815</td><td>3</td></tr><tr><td>SO71938</td><td>42</td></tr><tr><td>SO71846</td><td>4</td></tr><tr><td>SO71783</td><td>43</td></tr><tr><td>SO71858</td><td>17</td></tr><tr><td>SO71780</td><td>29</td></tr><tr><td>SO71902</td><td>50</td></tr><tr><td>SO71899</td><td>8</td></tr><tr><td>SO71856</td><td>2</td></tr><tr><td>SO71816</td><td>7</td></tr><tr><td>SO71784</td><td>43</td></tr><tr><td>SO71797</td><td>46</td></tr><tr><td>SO71936</td><td>46</td></tr><tr><td>SO71897</td><td>8</td></tr><tr><td>SO71845</td><td>31</td></tr><tr><td>SO71923</td><td>3</td></tr><tr><td>SO71796</td><td>20</td></tr><tr><td>SO71782</td><td>43</td></tr><tr><td>SO71920</td><td>6</td></tr><tr><td>SO71915</td><td>5</td></tr><tr><td>SO71774</td><td>2</td></tr><tr><td>SO71832</td><td>30</td></tr><tr><td>SO71895</td><td>3</td></tr><tr><td>SO71898</td><td>28</td></tr><tr><td>SO71935</td><td>6</td></tr><tr><td>SO71885</td><td>3</td></tr><tr><td>SO71863</td><td>7</td></tr></tbody></table></div>

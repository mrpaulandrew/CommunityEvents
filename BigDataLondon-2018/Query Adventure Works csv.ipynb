# %%
#This sample code loads the file into a data frame and shows the first 10 results.
df = (spark.read.option("inferSchema", "true")
.option("header", "true")
.csv('/RAW/AdventureWorks/Address.csv'))
df.show(10)
